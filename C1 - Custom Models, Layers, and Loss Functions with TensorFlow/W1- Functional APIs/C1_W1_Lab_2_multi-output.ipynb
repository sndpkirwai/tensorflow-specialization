# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.005)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 944us/sample - loss: 471.0252 - y1_output_loss: 118.7085 - y2_output_loss: 348.2991 - y1_output_root_mean_squared_error: 10.9407 - y2_output_root_mean_squared_error: 18.7437 - val_loss: 235.3386 - val_y1_output_loss: 20.7958 - val_y2_output_loss: 209.6190 - val_y1_output_root_mean_squared_error: 4.6425 - val_y2_output_root_mean_squared_error: 14.6214
# Epoch 2/500
# 614/614 [==============================] - 0s 147us/sample - loss: 45.1961 - y1_output_loss: 12.4834 - y2_output_loss: 32.5861 - y1_output_root_mean_squared_error: 3.5244 - y2_output_root_mean_squared_error: 5.7249 - val_loss: 41.7810 - val_y1_output_loss: 12.2016 - val_y2_output_loss: 28.5603 - val_y1_output_root_mean_squared_error: 3.5470 - val_y2_output_root_mean_squared_error: 5.4037
# Epoch 3/500
# 614/614 [==============================] - 0s 157us/sample - loss: 44.5911 - y1_output_loss: 11.5827 - y2_output_loss: 32.9244 - y1_output_root_mean_squared_error: 3.4124 - y2_output_root_mean_squared_error: 5.7399 - val_loss: 29.3055 - val_y1_output_loss: 11.0594 - val_y2_output_loss: 17.9955 - val_y1_output_root_mean_squared_error: 3.3506 - val_y2_output_root_mean_squared_error: 4.2519
# Epoch 4/500
# 614/614 [==============================] - 0s 142us/sample - loss: 27.3503 - y1_output_loss: 8.3161 - y2_output_loss: 18.9324 - y1_output_root_mean_squared_error: 2.8908 - y2_output_root_mean_squared_error: 4.3582 - val_loss: 103.9172 - val_y1_output_loss: 17.3110 - val_y2_output_loss: 84.2579 - val_y1_output_root_mean_squared_error: 4.2262 - val_y2_output_root_mean_squared_error: 9.2766
# Epoch 5/500
# 614/614 [==============================] - 0s 141us/sample - loss: 26.2616 - y1_output_loss: 8.5316 - y2_output_loss: 17.5945 - y1_output_root_mean_squared_error: 2.9328 - y2_output_root_mean_squared_error: 4.2024 - val_loss: 21.8320 - val_y1_output_loss: 8.9038 - val_y2_output_loss: 12.7567 - val_y1_output_root_mean_squared_error: 2.9885 - val_y2_output_root_mean_squared_error: 3.5917
# Epoch 6/500
# 614/614 [==============================] - 0s 142us/sample - loss: 25.9910 - y1_output_loss: 8.0406 - y2_output_loss: 18.4121 - y1_output_root_mean_squared_error: 2.8371 - y2_output_root_mean_squared_error: 4.2358 - val_loss: 55.6367 - val_y1_output_loss: 6.1252 - val_y2_output_loss: 48.4577 - val_y1_output_root_mean_squared_error: 2.5121 - val_y2_output_root_mean_squared_error: 7.0232
# Epoch 7/500
# 614/614 [==============================] - 0s 142us/sample - loss: 20.6216 - y1_output_loss: 6.0651 - y2_output_loss: 14.5024 - y1_output_root_mean_squared_error: 2.4717 - y2_output_root_mean_squared_error: 3.8095 - val_loss: 25.7996 - val_y1_output_loss: 6.1691 - val_y2_output_loss: 19.2014 - val_y1_output_root_mean_squared_error: 2.5002 - val_y2_output_root_mean_squared_error: 4.4214
# Epoch 8/500
# 614/614 [==============================] - 0s 140us/sample - loss: 18.7659 - y1_output_loss: 5.4297 - y2_output_loss: 13.2508 - y1_output_root_mean_squared_error: 2.3365 - y2_output_root_mean_squared_error: 3.6478 - val_loss: 22.7549 - val_y1_output_loss: 8.5965 - val_y2_output_loss: 13.6815 - val_y1_output_root_mean_squared_error: 2.9604 - val_y2_output_root_mean_squared_error: 3.7404
# Epoch 9/500
# 614/614 [==============================] - 0s 137us/sample - loss: 14.6945 - y1_output_loss: 4.1417 - y2_output_loss: 10.6165 - y1_output_root_mean_squared_error: 2.0385 - y2_output_root_mean_squared_error: 3.2464 - val_loss: 38.1267 - val_y1_output_loss: 5.1440 - val_y2_output_loss: 32.1216 - val_y1_output_root_mean_squared_error: 2.3014 - val_y2_output_root_mean_squared_error: 5.7297
# Epoch 10/500
# 614/614 [==============================] - 0s 135us/sample - loss: 18.8664 - y1_output_loss: 4.9665 - y2_output_loss: 13.7705 - y1_output_root_mean_squared_error: 2.2385 - y2_output_root_mean_squared_error: 3.7223 - val_loss: 128.5207 - val_y1_output_loss: 16.6922 - val_y2_output_loss: 110.8064 - val_y1_output_root_mean_squared_error: 4.0826 - val_y2_output_root_mean_squared_error: 10.5761
# Epoch 11/500
# 614/614 [==============================] - 0s 140us/sample - loss: 15.5727 - y1_output_loss: 4.2980 - y2_output_loss: 11.1687 - y1_output_root_mean_squared_error: 2.0809 - y2_output_root_mean_squared_error: 3.3530 - val_loss: 9.1874 - val_y1_output_loss: 2.7542 - val_y2_output_loss: 6.3510 - val_y1_output_root_mean_squared_error: 1.6666 - val_y2_output_root_mean_squared_error: 2.5317
# Epoch 12/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.7422 - y1_output_loss: 2.7463 - y2_output_loss: 7.7191 - y1_output_root_mean_squared_error: 1.6250 - y2_output_root_mean_squared_error: 2.6649 - val_loss: 62.2403 - val_y1_output_loss: 11.5831 - val_y2_output_loss: 48.6738 - val_y1_output_root_mean_squared_error: 3.4568 - val_y2_output_root_mean_squared_error: 7.0916
# Epoch 13/500
# 614/614 [==============================] - 0s 144us/sample - loss: 16.6710 - y1_output_loss: 4.4989 - y2_output_loss: 12.0586 - y1_output_root_mean_squared_error: 2.1263 - y2_output_root_mean_squared_error: 3.4856 - val_loss: 15.5329 - val_y1_output_loss: 5.2324 - val_y2_output_loss: 9.9488 - val_y1_output_root_mean_squared_error: 2.3169 - val_y2_output_root_mean_squared_error: 3.1882
# Epoch 14/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.6658 - y1_output_loss: 2.6297 - y2_output_loss: 6.9730 - y1_output_root_mean_squared_error: 1.6248 - y2_output_root_mean_squared_error: 2.6506 - val_loss: 8.6795 - val_y1_output_loss: 3.9499 - val_y2_output_loss: 5.0227 - val_y1_output_root_mean_squared_error: 1.9334 - val_y2_output_root_mean_squared_error: 2.2230
# Epoch 15/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.7539 - y1_output_loss: 1.6650 - y2_output_loss: 4.0977 - y1_output_root_mean_squared_error: 1.2854 - y2_output_root_mean_squared_error: 2.0253 - val_loss: 6.2060 - val_y1_output_loss: 1.3153 - val_y2_output_loss: 4.6974 - val_y1_output_root_mean_squared_error: 1.1582 - val_y2_output_root_mean_squared_error: 2.2056
# Epoch 16/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.6426 - y1_output_loss: 1.7165 - y2_output_loss: 5.8893 - y1_output_root_mean_squared_error: 1.3159 - y2_output_root_mean_squared_error: 2.4313 - val_loss: 8.8869 - val_y1_output_loss: 2.8918 - val_y2_output_loss: 6.1339 - val_y1_output_root_mean_squared_error: 1.6759 - val_y2_output_root_mean_squared_error: 2.4654
# Epoch 17/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.4842 - y1_output_loss: 1.4034 - y2_output_loss: 7.0050 - y1_output_root_mean_squared_error: 1.1890 - y2_output_root_mean_squared_error: 2.6591 - val_loss: 4.8497 - val_y1_output_loss: 0.9305 - val_y2_output_loss: 3.7942 - val_y1_output_root_mean_squared_error: 0.9766 - val_y2_output_root_mean_squared_error: 1.9738
# Epoch 18/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.9739 - y1_output_loss: 2.3160 - y2_output_loss: 6.6180 - y1_output_root_mean_squared_error: 1.5275 - y2_output_root_mean_squared_error: 2.5769 - val_loss: 8.1310 - val_y1_output_loss: 3.1551 - val_y2_output_loss: 4.6989 - val_y1_output_root_mean_squared_error: 1.8067 - val_y2_output_root_mean_squared_error: 2.2061
# Epoch 19/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.3252 - y1_output_loss: 1.1030 - y2_output_loss: 4.1785 - y1_output_root_mean_squared_error: 1.0540 - y2_output_root_mean_squared_error: 2.0529 - val_loss: 4.3217 - val_y1_output_loss: 0.7169 - val_y2_output_loss: 3.4822 - val_y1_output_root_mean_squared_error: 0.8548 - val_y2_output_root_mean_squared_error: 1.8950
# Epoch 20/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.8338 - y1_output_loss: 1.3649 - y2_output_loss: 5.4724 - y1_output_root_mean_squared_error: 1.1738 - y2_output_root_mean_squared_error: 2.3358 - val_loss: 15.4231 - val_y1_output_loss: 1.8580 - val_y2_output_loss: 13.2663 - val_y1_output_root_mean_squared_error: 1.3782 - val_y2_output_root_mean_squared_error: 3.6774
# Epoch 21/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.5050 - y1_output_loss: 1.2129 - y2_output_loss: 6.2353 - y1_output_root_mean_squared_error: 1.1054 - y2_output_root_mean_squared_error: 2.5066 - val_loss: 4.6637 - val_y1_output_loss: 1.0709 - val_y2_output_loss: 3.4922 - val_y1_output_root_mean_squared_error: 1.0362 - val_y2_output_root_mean_squared_error: 1.8947
# Epoch 22/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.3258 - y1_output_loss: 0.8662 - y2_output_loss: 3.6840 - y1_output_root_mean_squared_error: 0.9246 - y2_output_root_mean_squared_error: 1.8630 - val_loss: 46.5100 - val_y1_output_loss: 5.3324 - val_y2_output_loss: 40.0632 - val_y1_output_root_mean_squared_error: 2.3404 - val_y2_output_root_mean_squared_error: 6.4057
# Epoch 23/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.0759 - y1_output_loss: 1.3183 - y2_output_loss: 5.7195 - y1_output_root_mean_squared_error: 1.1500 - y2_output_root_mean_squared_error: 2.3986 - val_loss: 7.7302 - val_y1_output_loss: 0.9424 - val_y2_output_loss: 6.5596 - val_y1_output_root_mean_squared_error: 0.9734 - val_y2_output_root_mean_squared_error: 2.6044
# Epoch 24/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.2333 - y1_output_loss: 0.5778 - y2_output_loss: 3.6666 - y1_output_root_mean_squared_error: 0.7588 - y2_output_root_mean_squared_error: 1.9125 - val_loss: 8.0840 - val_y1_output_loss: 0.9417 - val_y2_output_loss: 6.9805 - val_y1_output_root_mean_squared_error: 0.9799 - val_y2_output_root_mean_squared_error: 2.6691
# Epoch 25/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.3690 - y1_output_loss: 1.0888 - y2_output_loss: 5.2439 - y1_output_root_mean_squared_error: 1.0456 - y2_output_root_mean_squared_error: 2.2969 - val_loss: 4.5216 - val_y1_output_loss: 0.5550 - val_y2_output_loss: 3.8467 - val_y1_output_root_mean_squared_error: 0.7530 - val_y2_output_root_mean_squared_error: 1.9886
# Epoch 26/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4633 - y1_output_loss: 0.6468 - y2_output_loss: 2.8769 - y1_output_root_mean_squared_error: 0.8055 - y2_output_root_mean_squared_error: 1.6776 - val_loss: 13.1326 - val_y1_output_loss: 0.6178 - val_y2_output_loss: 12.2796 - val_y1_output_root_mean_squared_error: 0.7993 - val_y2_output_root_mean_squared_error: 3.5346
# Epoch 27/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0726 - y1_output_loss: 0.6282 - y2_output_loss: 3.4203 - y1_output_root_mean_squared_error: 0.7953 - y2_output_root_mean_squared_error: 1.8547 - val_loss: 3.9237 - val_y1_output_loss: 0.7125 - val_y2_output_loss: 3.1434 - val_y1_output_root_mean_squared_error: 0.8312 - val_y2_output_root_mean_squared_error: 1.7980
# Epoch 28/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.2572 - y1_output_loss: 0.7629 - y2_output_loss: 3.4866 - y1_output_root_mean_squared_error: 0.8761 - y2_output_root_mean_squared_error: 1.8681 - val_loss: 4.9578 - val_y1_output_loss: 0.7426 - val_y2_output_loss: 4.1085 - val_y1_output_root_mean_squared_error: 0.8693 - val_y2_output_root_mean_squared_error: 2.0499
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7561 - y1_output_loss: 0.6370 - y2_output_loss: 3.0918 - y1_output_root_mean_squared_error: 0.8003 - y2_output_root_mean_squared_error: 1.7651 - val_loss: 3.3507 - val_y1_output_loss: 0.5261 - val_y2_output_loss: 2.7260 - val_y1_output_root_mean_squared_error: 0.7328 - val_y2_output_root_mean_squared_error: 1.6774
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.7201 - y1_output_loss: 0.5127 - y2_output_loss: 3.1842 - y1_output_root_mean_squared_error: 0.7186 - y2_output_root_mean_squared_error: 1.7899 - val_loss: 3.6249 - val_y1_output_loss: 0.5942 - val_y2_output_loss: 3.0371 - val_y1_output_root_mean_squared_error: 0.7615 - val_y2_output_root_mean_squared_error: 1.7450
# Epoch 31/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.1332 - y1_output_loss: 0.8593 - y2_output_loss: 4.2316 - y1_output_root_mean_squared_error: 0.9308 - y2_output_root_mean_squared_error: 2.0656 - val_loss: 3.6870 - val_y1_output_loss: 0.8612 - val_y2_output_loss: 2.7036 - val_y1_output_root_mean_squared_error: 0.9395 - val_y2_output_root_mean_squared_error: 1.6746
# Epoch 32/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.3873 - y1_output_loss: 0.6802 - y2_output_loss: 3.6755 - y1_output_root_mean_squared_error: 0.8261 - y2_output_root_mean_squared_error: 1.9248 - val_loss: 4.7131 - val_y1_output_loss: 1.1035 - val_y2_output_loss: 3.4541 - val_y1_output_root_mean_squared_error: 1.0654 - val_y2_output_root_mean_squared_error: 1.8916
# Epoch 33/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7353 - y1_output_loss: 0.4855 - y2_output_loss: 2.2752 - y1_output_root_mean_squared_error: 0.6934 - y2_output_root_mean_squared_error: 1.5015 - val_loss: 8.2809 - val_y1_output_loss: 2.1146 - val_y2_output_loss: 5.9115 - val_y1_output_root_mean_squared_error: 1.4777 - val_y2_output_root_mean_squared_error: 2.4693
# Epoch 34/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4274 - y1_output_loss: 0.5022 - y2_output_loss: 2.9613 - y1_output_root_mean_squared_error: 0.7060 - y2_output_root_mean_squared_error: 1.7114 - val_loss: 7.8774 - val_y1_output_loss: 0.6563 - val_y2_output_loss: 7.0791 - val_y1_output_root_mean_squared_error: 0.8223 - val_y2_output_root_mean_squared_error: 2.6835
# Epoch 35/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.8464 - y1_output_loss: 0.6068 - y2_output_loss: 3.2178 - y1_output_root_mean_squared_error: 0.7757 - y2_output_root_mean_squared_error: 1.8013 - val_loss: 5.4055 - val_y1_output_loss: 0.9990 - val_y2_output_loss: 4.3249 - val_y1_output_root_mean_squared_error: 1.0079 - val_y2_output_root_mean_squared_error: 2.0951
# Epoch 36/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8315 - y1_output_loss: 0.6358 - y2_output_loss: 3.1648 - y1_output_root_mean_squared_error: 0.7986 - y2_output_root_mean_squared_error: 1.7871 - val_loss: 3.5192 - val_y1_output_loss: 0.6638 - val_y2_output_loss: 2.7577 - val_y1_output_root_mean_squared_error: 0.8167 - val_y2_output_root_mean_squared_error: 1.6888
# Epoch 37/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.6634 - y1_output_loss: 0.5248 - y2_output_loss: 3.1530 - y1_output_root_mean_squared_error: 0.7198 - y2_output_root_mean_squared_error: 1.7735 - val_loss: 8.0599 - val_y1_output_loss: 0.9830 - val_y2_output_loss: 6.9066 - val_y1_output_root_mean_squared_error: 0.9988 - val_y2_output_root_mean_squared_error: 2.6575
# Epoch 38/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.2481 - y1_output_loss: 0.5081 - y2_output_loss: 2.7251 - y1_output_root_mean_squared_error: 0.7119 - y2_output_root_mean_squared_error: 1.6557 - val_loss: 3.3935 - val_y1_output_loss: 0.7620 - val_y2_output_loss: 2.5147 - val_y1_output_root_mean_squared_error: 0.8866 - val_y2_output_root_mean_squared_error: 1.6148
# Epoch 39/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4949 - y1_output_loss: 0.5065 - y2_output_loss: 2.9575 - y1_output_root_mean_squared_error: 0.7144 - y2_output_root_mean_squared_error: 1.7276 - val_loss: 3.4212 - val_y1_output_loss: 0.4813 - val_y2_output_loss: 2.8202 - val_y1_output_root_mean_squared_error: 0.7029 - val_y2_output_root_mean_squared_error: 1.7109
# Epoch 40/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.8286 - y1_output_loss: 0.5510 - y2_output_loss: 3.3173 - y1_output_root_mean_squared_error: 0.7372 - y2_output_root_mean_squared_error: 1.8125 - val_loss: 8.4733 - val_y1_output_loss: 2.6070 - val_y2_output_loss: 5.5594 - val_y1_output_root_mean_squared_error: 1.6430 - val_y2_output_root_mean_squared_error: 2.4029
# Epoch 41/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.9731 - y1_output_loss: 0.5257 - y2_output_loss: 2.5429 - y1_output_root_mean_squared_error: 0.7280 - y2_output_root_mean_squared_error: 1.5631 - val_loss: 19.2926 - val_y1_output_loss: 2.2773 - val_y2_output_loss: 16.5102 - val_y1_output_root_mean_squared_error: 1.5367 - val_y2_output_root_mean_squared_error: 4.1148
# Epoch 42/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6966 - y1_output_loss: 0.4790 - y2_output_loss: 2.2208 - y1_output_root_mean_squared_error: 0.6950 - y2_output_root_mean_squared_error: 1.4878 - val_loss: 8.0765 - val_y1_output_loss: 0.6364 - val_y2_output_loss: 7.2528 - val_y1_output_root_mean_squared_error: 0.8033 - val_y2_output_root_mean_squared_error: 2.7260
# Epoch 43/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4436 - y1_output_loss: 0.3917 - y2_output_loss: 2.0461 - y1_output_root_mean_squared_error: 0.6286 - y2_output_root_mean_squared_error: 1.4312 - val_loss: 5.5037 - val_y1_output_loss: 0.4190 - val_y2_output_loss: 4.9443 - val_y1_output_root_mean_squared_error: 0.6545 - val_y2_output_root_mean_squared_error: 2.2529
# Epoch 44/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.3856 - y1_output_loss: 0.4187 - y2_output_loss: 1.9723 - y1_output_root_mean_squared_error: 0.6486 - y2_output_root_mean_squared_error: 1.4017 - val_loss: 5.4145 - val_y1_output_loss: 0.6235 - val_y2_output_loss: 4.7325 - val_y1_output_root_mean_squared_error: 0.7941 - val_y2_output_root_mean_squared_error: 2.1872
# Epoch 45/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4778 - y1_output_loss: 0.3861 - y2_output_loss: 2.0724 - y1_output_root_mean_squared_error: 0.6214 - y2_output_root_mean_squared_error: 1.4463 - val_loss: 3.2828 - val_y1_output_loss: 0.4479 - val_y2_output_loss: 2.7796 - val_y1_output_root_mean_squared_error: 0.6772 - val_y2_output_root_mean_squared_error: 1.6805
# Epoch 46/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7618 - y1_output_loss: 0.4412 - y2_output_loss: 2.3190 - y1_output_root_mean_squared_error: 0.6656 - y2_output_root_mean_squared_error: 1.5228 - val_loss: 3.4749 - val_y1_output_loss: 0.6457 - val_y2_output_loss: 2.7270 - val_y1_output_root_mean_squared_error: 0.8135 - val_y2_output_root_mean_squared_error: 1.6772
# Epoch 47/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7883 - y1_output_loss: 0.3629 - y2_output_loss: 2.4025 - y1_output_root_mean_squared_error: 0.6036 - y2_output_root_mean_squared_error: 1.5569 - val_loss: 2.4344 - val_y1_output_loss: 0.4292 - val_y2_output_loss: 1.9397 - val_y1_output_root_mean_squared_error: 0.6562 - val_y2_output_root_mean_squared_error: 1.4156
# Epoch 48/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3548 - y1_output_loss: 0.3835 - y2_output_loss: 1.9495 - y1_output_root_mean_squared_error: 0.6217 - y2_output_root_mean_squared_error: 1.4030 - val_loss: 1.9885 - val_y1_output_loss: 0.2966 - val_y2_output_loss: 1.6230 - val_y1_output_root_mean_squared_error: 0.5533 - val_y2_output_root_mean_squared_error: 1.2971
# Epoch 49/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7810 - y1_output_loss: 0.3689 - y2_output_loss: 2.4168 - y1_output_root_mean_squared_error: 0.6075 - y2_output_root_mean_squared_error: 1.5530 - val_loss: 9.6728 - val_y1_output_loss: 0.6740 - val_y2_output_loss: 8.6752 - val_y1_output_root_mean_squared_error: 0.8350 - val_y2_output_root_mean_squared_error: 2.9959
# Epoch 50/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.6662 - y1_output_loss: 0.4261 - y2_output_loss: 2.2185 - y1_output_root_mean_squared_error: 0.6546 - y2_output_root_mean_squared_error: 1.4959 - val_loss: 11.7183 - val_y1_output_loss: 1.6245 - val_y2_output_loss: 9.7093 - val_y1_output_root_mean_squared_error: 1.2949 - val_y2_output_root_mean_squared_error: 3.1688
# Epoch 51/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4070 - y1_output_loss: 0.5059 - y2_output_loss: 2.8858 - y1_output_root_mean_squared_error: 0.7073 - y2_output_root_mean_squared_error: 1.7049 - val_loss: 2.6180 - val_y1_output_loss: 0.4611 - val_y2_output_loss: 2.0635 - val_y1_output_root_mean_squared_error: 0.6898 - val_y2_output_root_mean_squared_error: 1.4636
# Epoch 52/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.4873 - y1_output_loss: 0.3966 - y2_output_loss: 2.0708 - y1_output_root_mean_squared_error: 0.6323 - y2_output_root_mean_squared_error: 1.4448 - val_loss: 2.9072 - val_y1_output_loss: 0.4117 - val_y2_output_loss: 2.4043 - val_y1_output_root_mean_squared_error: 0.6515 - val_y2_output_root_mean_squared_error: 1.5757
# Epoch 53/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.0411 - y1_output_loss: 0.3278 - y2_output_loss: 1.7105 - y1_output_root_mean_squared_error: 0.5729 - y2_output_root_mean_squared_error: 1.3088 - val_loss: 2.6084 - val_y1_output_loss: 0.6092 - val_y2_output_loss: 1.9172 - val_y1_output_root_mean_squared_error: 0.7926 - val_y2_output_root_mean_squared_error: 1.4072
# Epoch 54/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3157 - y1_output_loss: 0.4222 - y2_output_loss: 1.8890 - y1_output_root_mean_squared_error: 0.6510 - y2_output_root_mean_squared_error: 1.3755 - val_loss: 3.8005 - val_y1_output_loss: 0.7685 - val_y2_output_loss: 2.9052 - val_y1_output_root_mean_squared_error: 0.8862 - val_y2_output_root_mean_squared_error: 1.7364
# Epoch 55/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1930 - y1_output_loss: 0.3369 - y2_output_loss: 1.8385 - y1_output_root_mean_squared_error: 0.5830 - y2_output_root_mean_squared_error: 1.3613 - val_loss: 2.4129 - val_y1_output_loss: 0.3787 - val_y2_output_loss: 1.9495 - val_y1_output_root_mean_squared_error: 0.6246 - val_y2_output_root_mean_squared_error: 1.4222
# Epoch 56/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.0964 - y1_output_loss: 0.2989 - y2_output_loss: 1.7817 - y1_output_root_mean_squared_error: 0.5466 - y2_output_root_mean_squared_error: 1.3407 - val_loss: 2.2637 - val_y1_output_loss: 0.3921 - val_y2_output_loss: 1.8165 - val_y1_output_root_mean_squared_error: 0.6359 - val_y2_output_root_mean_squared_error: 1.3636
# Epoch 57/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3054 - y1_output_loss: 0.3012 - y2_output_loss: 2.0084 - y1_output_root_mean_squared_error: 0.5456 - y2_output_root_mean_squared_error: 1.4169 - val_loss: 6.5370 - val_y1_output_loss: 0.4219 - val_y2_output_loss: 5.9590 - val_y1_output_root_mean_squared_error: 0.6530 - val_y2_output_root_mean_squared_error: 2.4720
# Epoch 58/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5669 - y1_output_loss: 0.3668 - y2_output_loss: 2.2979 - y1_output_root_mean_squared_error: 0.5995 - y2_output_root_mean_squared_error: 1.4858 - val_loss: 8.0236 - val_y1_output_loss: 0.8589 - val_y2_output_loss: 6.9392 - val_y1_output_root_mean_squared_error: 0.9400 - val_y2_output_root_mean_squared_error: 2.6721
# Epoch 59/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8300 - y1_output_loss: 0.4064 - y2_output_loss: 2.4134 - y1_output_root_mean_squared_error: 0.6401 - y2_output_root_mean_squared_error: 1.5557 - val_loss: 2.9203 - val_y1_output_loss: 0.4100 - val_y2_output_loss: 2.4142 - val_y1_output_root_mean_squared_error: 0.6512 - val_y2_output_root_mean_squared_error: 1.5800
# Epoch 60/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3458 - y1_output_loss: 0.3604 - y2_output_loss: 1.9777 - y1_output_root_mean_squared_error: 0.6029 - y2_output_root_mean_squared_error: 1.4080 - val_loss: 8.3103 - val_y1_output_loss: 0.4786 - val_y2_output_loss: 7.5934 - val_y1_output_root_mean_squared_error: 0.7018 - val_y2_output_root_mean_squared_error: 2.7960
# Epoch 61/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.0344 - y1_output_loss: 0.2991 - y2_output_loss: 1.7190 - y1_output_root_mean_squared_error: 0.5478 - y2_output_root_mean_squared_error: 1.3169 - val_loss: 1.6727 - val_y1_output_loss: 0.2819 - val_y2_output_loss: 1.3496 - val_y1_output_root_mean_squared_error: 0.5336 - val_y2_output_root_mean_squared_error: 1.1781
# Epoch 62/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.9127 - y1_output_loss: 0.3241 - y2_output_loss: 1.5784 - y1_output_root_mean_squared_error: 0.5699 - y2_output_root_mean_squared_error: 1.2601 - val_loss: 2.6511 - val_y1_output_loss: 0.3779 - val_y2_output_loss: 2.1963 - val_y1_output_root_mean_squared_error: 0.6221 - val_y2_output_root_mean_squared_error: 1.5047
# Epoch 63/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.4855 - y1_output_loss: 0.2927 - y2_output_loss: 1.3466 - y1_output_root_mean_squared_error: 0.5421 - y2_output_root_mean_squared_error: 1.0916 - val_loss: 39.9705 - val_y1_output_loss: 2.1155 - val_y2_output_loss: 36.8681 - val_y1_output_root_mean_squared_error: 1.4785 - val_y2_output_root_mean_squared_error: 6.1469
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.6051 - y1_output_loss: 0.4427 - y2_output_loss: 2.1457 - y1_output_root_mean_squared_error: 0.6654 - y2_output_root_mean_squared_error: 1.4705 - val_loss: 1.9526 - val_y1_output_loss: 0.3989 - val_y2_output_loss: 1.4849 - val_y1_output_root_mean_squared_error: 0.6425 - val_y2_output_root_mean_squared_error: 1.2409
# Epoch 65/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2276 - y1_output_loss: 0.3419 - y2_output_loss: 1.8814 - y1_output_root_mean_squared_error: 0.5862 - y2_output_root_mean_squared_error: 1.3726 - val_loss: 2.0886 - val_y1_output_loss: 0.4218 - val_y2_output_loss: 1.6331 - val_y1_output_root_mean_squared_error: 0.6531 - val_y2_output_root_mean_squared_error: 1.2892
# Epoch 66/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.1614 - y1_output_loss: 0.2586 - y2_output_loss: 0.9003 - y1_output_root_mean_squared_error: 0.5090 - y2_output_root_mean_squared_error: 0.9499 - val_loss: 1.8218 - val_y1_output_loss: 0.3010 - val_y2_output_loss: 1.4784 - val_y1_output_root_mean_squared_error: 0.5517 - val_y2_output_root_mean_squared_error: 1.2318
# Epoch 67/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.8828 - y1_output_loss: 0.3133 - y2_output_loss: 1.5536 - y1_output_root_mean_squared_error: 0.5623 - y2_output_root_mean_squared_error: 1.2516 - val_loss: 2.2581 - val_y1_output_loss: 0.4444 - val_y2_output_loss: 1.7549 - val_y1_output_root_mean_squared_error: 0.6726 - val_y2_output_root_mean_squared_error: 1.3438
# Epoch 68/500
# 614/614 [==============================] - 0s 139us/sample - loss: 1.3813 - y1_output_loss: 0.2503 - y2_output_loss: 1.1255 - y1_output_root_mean_squared_error: 0.4994 - y2_output_root_mean_squared_error: 1.0639 - val_loss: 2.0419 - val_y1_output_loss: 0.4027 - val_y2_output_loss: 1.5923 - val_y1_output_root_mean_squared_error: 0.6428 - val_y2_output_root_mean_squared_error: 1.2762
# Epoch 69/500
# 614/614 [==============================] - 0s 133us/sample - loss: 1.5518 - y1_output_loss: 0.2617 - y2_output_loss: 1.2965 - y1_output_root_mean_squared_error: 0.5134 - y2_output_root_mean_squared_error: 1.1350 - val_loss: 2.0774 - val_y1_output_loss: 0.3352 - val_y2_output_loss: 1.6813 - val_y1_output_root_mean_squared_error: 0.5822 - val_y2_output_root_mean_squared_error: 1.3185
# Epoch 70/500
# 614/614 [==============================] - 0s 130us/sample - loss: 1.2409 - y1_output_loss: 0.2736 - y2_output_loss: 0.9927 - y1_output_root_mean_squared_error: 0.5221 - y2_output_root_mean_squared_error: 0.9841 - val_loss: 6.6402 - val_y1_output_loss: 0.3085 - val_y2_output_loss: 6.2318 - val_y1_output_root_mean_squared_error: 0.5656 - val_y2_output_root_mean_squared_error: 2.5140
# Epoch 71/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.0844 - y1_output_loss: 0.3325 - y2_output_loss: 1.7504 - y1_output_root_mean_squared_error: 0.5763 - y2_output_root_mean_squared_error: 1.3237 - val_loss: 2.7763 - val_y1_output_loss: 0.3482 - val_y2_output_loss: 2.3565 - val_y1_output_root_mean_squared_error: 0.6007 - val_y2_output_root_mean_squared_error: 1.5542
# Epoch 72/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.8416 - y1_output_loss: 0.3981 - y2_output_loss: 1.4603 - y1_output_root_mean_squared_error: 0.6335 - y2_output_root_mean_squared_error: 1.2001 - val_loss: 4.0946 - val_y1_output_loss: 0.5280 - val_y2_output_loss: 3.4354 - val_y1_output_root_mean_squared_error: 0.7352 - val_y2_output_root_mean_squared_error: 1.8852
# Epoch 73/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.4312 - y1_output_loss: 0.2558 - y2_output_loss: 1.1671 - y1_output_root_mean_squared_error: 0.5076 - y2_output_root_mean_squared_error: 1.0833 - val_loss: 1.6198 - val_y1_output_loss: 0.3010 - val_y2_output_loss: 1.2775 - val_y1_output_root_mean_squared_error: 0.5583 - val_y2_output_root_mean_squared_error: 1.1437
# Epoch 74/500
# 614/614 [==============================] - 0s 140us/sample - loss: 1.2452 - y1_output_loss: 0.2302 - y2_output_loss: 1.0058 - y1_output_root_mean_squared_error: 0.4814 - y2_output_root_mean_squared_error: 1.0067 - val_loss: 1.8937 - val_y1_output_loss: 0.3096 - val_y2_output_loss: 1.5393 - val_y1_output_root_mean_squared_error: 0.5617 - val_y2_output_root_mean_squared_error: 1.2563
# Epoch 75/500
# 614/614 [==============================] - 0s 137us/sample - loss: 1.1509 - y1_output_loss: 0.2325 - y2_output_loss: 0.9083 - y1_output_root_mean_squared_error: 0.4837 - y2_output_root_mean_squared_error: 0.9576 - val_loss: 1.5155 - val_y1_output_loss: 0.3187 - val_y2_output_loss: 1.1567 - val_y1_output_root_mean_squared_error: 0.5680 - val_y2_output_root_mean_squared_error: 1.0922
# Epoch 76/500
# 614/614 [==============================] - 0s 142us/sample - loss: 1.5285 - y1_output_loss: 0.3002 - y2_output_loss: 1.2330 - y1_output_root_mean_squared_error: 0.5472 - y2_output_root_mean_squared_error: 1.1086 - val_loss: 1.5799 - val_y1_output_loss: 0.3937 - val_y2_output_loss: 1.1366 - val_y1_output_root_mean_squared_error: 0.6380 - val_y2_output_root_mean_squared_error: 1.0830
# Epoch 77/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.1283 - y1_output_loss: 0.2387 - y2_output_loss: 0.8904 - y1_output_root_mean_squared_error: 0.4901 - y2_output_root_mean_squared_error: 0.9424 - val_loss: 2.3704 - val_y1_output_loss: 0.2845 - val_y2_output_loss: 2.0110 - val_y1_output_root_mean_squared_error: 0.5405 - val_y2_output_root_mean_squared_error: 1.4416
# Epoch 78/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.0481 - y1_output_loss: 0.2393 - y2_output_loss: 0.7995 - y1_output_root_mean_squared_error: 0.4914 - y2_output_root_mean_squared_error: 0.8981 - val_loss: 1.6216 - val_y1_output_loss: 0.2556 - val_y2_output_loss: 1.3100 - val_y1_output_root_mean_squared_error: 0.5112 - val_y2_output_root_mean_squared_error: 1.1663
# Epoch 79/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.1400 - y1_output_loss: 0.2520 - y2_output_loss: 0.8904 - y1_output_root_mean_squared_error: 0.4929 - y2_output_root_mean_squared_error: 0.9471 - val_loss: 2.3114 - val_y1_output_loss: 0.8887 - val_y2_output_loss: 1.3887 - val_y1_output_root_mean_squared_error: 0.9489 - val_y2_output_root_mean_squared_error: 1.1879
# Epoch 80/500
# 614/614 [==============================] - 0s 134us/sample - loss: 1.1797 - y1_output_loss: 0.2986 - y2_output_loss: 0.8792 - y1_output_root_mean_squared_error: 0.5443 - y2_output_root_mean_squared_error: 0.9399 - val_loss: 1.4353 - val_y1_output_loss: 0.3305 - val_y2_output_loss: 1.0577 - val_y1_output_root_mean_squared_error: 0.5841 - val_y2_output_root_mean_squared_error: 1.0460
# Epoch 81/500
# 614/614 [==============================] - 0s 145us/sample - loss: 1.1383 - y1_output_loss: 0.2506 - y2_output_loss: 0.8846 - y1_output_root_mean_squared_error: 0.4998 - y2_output_root_mean_squared_error: 0.9426 - val_loss: 2.3560 - val_y1_output_loss: 0.3935 - val_y2_output_loss: 1.8969 - val_y1_output_root_mean_squared_error: 0.6327 - val_y2_output_root_mean_squared_error: 1.3985
# Epoch 82/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.9560 - y1_output_loss: 0.2132 - y2_output_loss: 0.7400 - y1_output_root_mean_squared_error: 0.4614 - y2_output_root_mean_squared_error: 0.8621 - val_loss: 1.2435 - val_y1_output_loss: 0.3165 - val_y2_output_loss: 0.9171 - val_y1_output_root_mean_squared_error: 0.5647 - val_y2_output_root_mean_squared_error: 0.9616
# Epoch 83/500
# 614/614 [==============================] - 0s 129us/sample - loss: 1.0732 - y1_output_loss: 0.2228 - y2_output_loss: 0.8420 - y1_output_root_mean_squared_error: 0.4728 - y2_output_root_mean_squared_error: 0.9218 - val_loss: 1.3903 - val_y1_output_loss: 0.3454 - val_y2_output_loss: 1.0062 - val_y1_output_root_mean_squared_error: 0.5901 - val_y2_output_root_mean_squared_error: 1.0208
# Epoch 84/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.3428 - y1_output_loss: 0.2783 - y2_output_loss: 1.0615 - y1_output_root_mean_squared_error: 0.5296 - y2_output_root_mean_squared_error: 1.0307 - val_loss: 3.3005 - val_y1_output_loss: 0.3320 - val_y2_output_loss: 2.8743 - val_y1_output_root_mean_squared_error: 0.5790 - val_y2_output_root_mean_squared_error: 1.7220
# Epoch 85/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.4723 - y1_output_loss: 0.3668 - y2_output_loss: 1.1029 - y1_output_root_mean_squared_error: 0.6081 - y2_output_root_mean_squared_error: 1.0500 - val_loss: 4.5111 - val_y1_output_loss: 0.5249 - val_y2_output_loss: 3.8629 - val_y1_output_root_mean_squared_error: 0.7370 - val_y2_output_root_mean_squared_error: 1.9920
# Epoch 86/500
# 614/614 [==============================] - 0s 131us/sample - loss: 1.2189 - y1_output_loss: 0.2774 - y2_output_loss: 0.9387 - y1_output_root_mean_squared_error: 0.5287 - y2_output_root_mean_squared_error: 0.9692 - val_loss: 3.2386 - val_y1_output_loss: 0.4025 - val_y2_output_loss: 2.7309 - val_y1_output_root_mean_squared_error: 0.6430 - val_y2_output_root_mean_squared_error: 1.6808
# Epoch 87/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.2562 - y1_output_loss: 0.2769 - y2_output_loss: 0.9818 - y1_output_root_mean_squared_error: 0.5266 - y2_output_root_mean_squared_error: 0.9894 - val_loss: 4.0610 - val_y1_output_loss: 0.4045 - val_y2_output_loss: 3.5446 - val_y1_output_root_mean_squared_error: 0.6436 - val_y2_output_root_mean_squared_error: 1.9097
# Epoch 88/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.8969 - y1_output_loss: 0.2132 - y2_output_loss: 0.6808 - y1_output_root_mean_squared_error: 0.4630 - y2_output_root_mean_squared_error: 0.8262 - val_loss: 1.4125 - val_y1_output_loss: 0.3341 - val_y2_output_loss: 1.0387 - val_y1_output_root_mean_squared_error: 0.5868 - val_y2_output_root_mean_squared_error: 1.0335
# Epoch 89/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.8125 - y1_output_loss: 0.2830 - y2_output_loss: 1.5228 - y1_output_root_mean_squared_error: 0.5321 - y2_output_root_mean_squared_error: 1.2367 - val_loss: 2.3999 - val_y1_output_loss: 0.4863 - val_y2_output_loss: 1.8310 - val_y1_output_root_mean_squared_error: 0.7087 - val_y2_output_root_mean_squared_error: 1.3776
# Epoch 90/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.7681 - y1_output_loss: 0.2042 - y2_output_loss: 0.5592 - y1_output_root_mean_squared_error: 0.4535 - y2_output_root_mean_squared_error: 0.7500 - val_loss: 1.4327 - val_y1_output_loss: 0.4097 - val_y2_output_loss: 0.9773 - val_y1_output_root_mean_squared_error: 0.6489 - val_y2_output_root_mean_squared_error: 1.0058
# Epoch 91/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7183 - y1_output_loss: 0.1845 - y2_output_loss: 0.5330 - y1_output_root_mean_squared_error: 0.4259 - y2_output_root_mean_squared_error: 0.7327 - val_loss: 1.2273 - val_y1_output_loss: 0.4563 - val_y2_output_loss: 0.7814 - val_y1_output_root_mean_squared_error: 0.6549 - val_y2_output_root_mean_squared_error: 0.8935
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7679 - y1_output_loss: 0.1858 - y2_output_loss: 0.5773 - y1_output_root_mean_squared_error: 0.4319 - y2_output_root_mean_squared_error: 0.7625 - val_loss: 1.1298 - val_y1_output_loss: 0.2305 - val_y2_output_loss: 0.8622 - val_y1_output_root_mean_squared_error: 0.4886 - val_y2_output_root_mean_squared_error: 0.9440
# Epoch 93/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.9694 - y1_output_loss: 0.2404 - y2_output_loss: 0.7409 - y1_output_root_mean_squared_error: 0.4730 - y2_output_root_mean_squared_error: 0.8635 - val_loss: 1.9674 - val_y1_output_loss: 0.9705 - val_y2_output_loss: 0.9762 - val_y1_output_root_mean_squared_error: 0.9781 - val_y2_output_root_mean_squared_error: 1.0054
# Epoch 94/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.8271 - y1_output_loss: 0.2634 - y2_output_loss: 0.5580 - y1_output_root_mean_squared_error: 0.5151 - y2_output_root_mean_squared_error: 0.7495 - val_loss: 1.4626 - val_y1_output_loss: 0.2914 - val_y2_output_loss: 1.1280 - val_y1_output_root_mean_squared_error: 0.5424 - val_y2_output_root_mean_squared_error: 1.0809
# Epoch 95/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.7008 - y1_output_loss: 0.2030 - y2_output_loss: 0.5008 - y1_output_root_mean_squared_error: 0.4523 - y2_output_root_mean_squared_error: 0.7044 - val_loss: 1.3823 - val_y1_output_loss: 0.3546 - val_y2_output_loss: 0.9796 - val_y1_output_root_mean_squared_error: 0.6057 - val_y2_output_root_mean_squared_error: 1.0077
# Epoch 96/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.8627 - y1_output_loss: 0.1933 - y2_output_loss: 0.6633 - y1_output_root_mean_squared_error: 0.4403 - y2_output_root_mean_squared_error: 0.8178 - val_loss: 1.4875 - val_y1_output_loss: 0.3175 - val_y2_output_loss: 1.1331 - val_y1_output_root_mean_squared_error: 0.5696 - val_y2_output_root_mean_squared_error: 1.0785
# Epoch 97/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7557 - y1_output_loss: 0.2558 - y2_output_loss: 0.4986 - y1_output_root_mean_squared_error: 0.5059 - y2_output_root_mean_squared_error: 0.7070 - val_loss: 1.5716 - val_y1_output_loss: 0.2475 - val_y2_output_loss: 1.2812 - val_y1_output_root_mean_squared_error: 0.5058 - val_y2_output_root_mean_squared_error: 1.1471
# Epoch 98/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.8301 - y1_output_loss: 0.2228 - y2_output_loss: 0.6041 - y1_output_root_mean_squared_error: 0.4720 - y2_output_root_mean_squared_error: 0.7793 - val_loss: 1.4227 - val_y1_output_loss: 0.3173 - val_y2_output_loss: 1.0752 - val_y1_output_root_mean_squared_error: 0.5679 - val_y2_output_root_mean_squared_error: 1.0489
# Epoch 99/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.8108 - y1_output_loss: 0.2113 - y2_output_loss: 0.5947 - y1_output_root_mean_squared_error: 0.4612 - y2_output_root_mean_squared_error: 0.7733 - val_loss: 1.8459 - val_y1_output_loss: 0.2750 - val_y2_output_loss: 1.5114 - val_y1_output_root_mean_squared_error: 0.5323 - val_y2_output_root_mean_squared_error: 1.2500
# Epoch 100/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.4110 - y1_output_loss: 0.2505 - y2_output_loss: 1.1543 - y1_output_root_mean_squared_error: 0.4991 - y2_output_root_mean_squared_error: 1.0779 - val_loss: 9.4885 - val_y1_output_loss: 2.4967 - val_y2_output_loss: 6.6589 - val_y1_output_root_mean_squared_error: 1.6059 - val_y2_output_root_mean_squared_error: 2.6286
# Epoch 101/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.9771 - y1_output_loss: 0.3048 - y2_output_loss: 0.6662 - y1_output_root_mean_squared_error: 0.5527 - y2_output_root_mean_squared_error: 0.8196 - val_loss: 1.1096 - val_y1_output_loss: 0.3024 - val_y2_output_loss: 0.7839 - val_y1_output_root_mean_squared_error: 0.5494 - val_y2_output_root_mean_squared_error: 0.8987
# Epoch 102/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.7981 - y1_output_loss: 0.1982 - y2_output_loss: 0.6002 - y1_output_root_mean_squared_error: 0.4464 - y2_output_root_mean_squared_error: 0.7739 - val_loss: 1.4573 - val_y1_output_loss: 0.2678 - val_y2_output_loss: 1.1486 - val_y1_output_root_mean_squared_error: 0.5218 - val_y2_output_root_mean_squared_error: 1.0886
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 1.2647 - y1_output_loss: 0.2779 - y2_output_loss: 0.9776 - y1_output_root_mean_squared_error: 0.5290 - y2_output_root_mean_squared_error: 0.9924 - val_loss: 1.0570 - val_y1_output_loss: 0.2307 - val_y2_output_loss: 0.7920 - val_y1_output_root_mean_squared_error: 0.4859 - val_y2_output_root_mean_squared_error: 0.9061
# Epoch 104/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.9806 - y1_output_loss: 0.2469 - y2_output_loss: 0.7275 - y1_output_root_mean_squared_error: 0.4970 - y2_output_root_mean_squared_error: 0.8565 - val_loss: 1.3283 - val_y1_output_loss: 0.3353 - val_y2_output_loss: 0.9527 - val_y1_output_root_mean_squared_error: 0.5836 - val_y2_output_root_mean_squared_error: 0.9938
# Epoch 105/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.8225 - y1_output_loss: 0.2009 - y2_output_loss: 0.6184 - y1_output_root_mean_squared_error: 0.4469 - y2_output_root_mean_squared_error: 0.7892 - val_loss: 1.3214 - val_y1_output_loss: 0.3765 - val_y2_output_loss: 0.9129 - val_y1_output_root_mean_squared_error: 0.6184 - val_y2_output_root_mean_squared_error: 0.9690
# Epoch 106/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6222 - y1_output_loss: 0.1704 - y2_output_loss: 0.4502 - y1_output_root_mean_squared_error: 0.4139 - y2_output_root_mean_squared_error: 0.6715 - val_loss: 1.5858 - val_y1_output_loss: 0.2945 - val_y2_output_loss: 1.2373 - val_y1_output_root_mean_squared_error: 0.5496 - val_y2_output_root_mean_squared_error: 1.1330
# Epoch 107/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6262 - y1_output_loss: 0.1745 - y2_output_loss: 0.4521 - y1_output_root_mean_squared_error: 0.4153 - y2_output_root_mean_squared_error: 0.6736 - val_loss: 2.0076 - val_y1_output_loss: 0.4306 - val_y2_output_loss: 1.5245 - val_y1_output_root_mean_squared_error: 0.6588 - val_y2_output_root_mean_squared_error: 1.2544
# Epoch 108/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6936 - y1_output_loss: 0.2026 - y2_output_loss: 0.4892 - y1_output_root_mean_squared_error: 0.4515 - y2_output_root_mean_squared_error: 0.6998 - val_loss: 1.3183 - val_y1_output_loss: 0.3291 - val_y2_output_loss: 0.9439 - val_y1_output_root_mean_squared_error: 0.5832 - val_y2_output_root_mean_squared_error: 0.9890
# Epoch 109/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.8149 - y1_output_loss: 0.2365 - y2_output_loss: 0.5741 - y1_output_root_mean_squared_error: 0.4860 - y2_output_root_mean_squared_error: 0.7607 - val_loss: 1.7875 - val_y1_output_loss: 0.8164 - val_y2_output_loss: 0.9450 - val_y1_output_root_mean_squared_error: 0.9021 - val_y2_output_root_mean_squared_error: 0.9867
# Epoch 110/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.7547 - y1_output_loss: 0.2174 - y2_output_loss: 0.5318 - y1_output_root_mean_squared_error: 0.4677 - y2_output_root_mean_squared_error: 0.7321 - val_loss: 1.0525 - val_y1_output_loss: 0.2276 - val_y2_output_loss: 0.7944 - val_y1_output_root_mean_squared_error: 0.4780 - val_y2_output_root_mean_squared_error: 0.9078
# Epoch 111/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5454 - y1_output_loss: 0.1674 - y2_output_loss: 0.3755 - y1_output_root_mean_squared_error: 0.4090 - y2_output_root_mean_squared_error: 0.6149 - val_loss: 1.0596 - val_y1_output_loss: 0.2295 - val_y2_output_loss: 0.7989 - val_y1_output_root_mean_squared_error: 0.4831 - val_y2_output_root_mean_squared_error: 0.9090
# Epoch 112/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6225 - y1_output_loss: 0.1837 - y2_output_loss: 0.4368 - y1_output_root_mean_squared_error: 0.4279 - y2_output_root_mean_squared_error: 0.6628 - val_loss: 1.0916 - val_y1_output_loss: 0.3304 - val_y2_output_loss: 0.7395 - val_y1_output_root_mean_squared_error: 0.5697 - val_y2_output_root_mean_squared_error: 0.8758
# Epoch 113/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6718 - y1_output_loss: 0.1983 - y2_output_loss: 0.4703 - y1_output_root_mean_squared_error: 0.4445 - y2_output_root_mean_squared_error: 0.6886 - val_loss: 1.3017 - val_y1_output_loss: 0.2615 - val_y2_output_loss: 0.9983 - val_y1_output_root_mean_squared_error: 0.5205 - val_y2_output_root_mean_squared_error: 1.0153
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6483 - y1_output_loss: 0.1728 - y2_output_loss: 0.4715 - y1_output_root_mean_squared_error: 0.4160 - y2_output_root_mean_squared_error: 0.6894 - val_loss: 1.3164 - val_y1_output_loss: 0.2961 - val_y2_output_loss: 0.9867 - val_y1_output_root_mean_squared_error: 0.5506 - val_y2_output_root_mean_squared_error: 1.0066
# Epoch 115/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.9575 - y1_output_loss: 0.1996 - y2_output_loss: 0.7498 - y1_output_root_mean_squared_error: 0.4479 - y2_output_root_mean_squared_error: 0.8700 - val_loss: 1.2579 - val_y1_output_loss: 0.2657 - val_y2_output_loss: 0.9523 - val_y1_output_root_mean_squared_error: 0.5226 - val_y2_output_root_mean_squared_error: 0.9924
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6810 - y1_output_loss: 0.1816 - y2_output_loss: 0.5004 - y1_output_root_mean_squared_error: 0.4246 - y2_output_root_mean_squared_error: 0.7076 - val_loss: 1.6289 - val_y1_output_loss: 0.2264 - val_y2_output_loss: 1.3507 - val_y1_output_root_mean_squared_error: 0.4835 - val_y2_output_root_mean_squared_error: 1.1812
# Epoch 117/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6428 - y1_output_loss: 0.1748 - y2_output_loss: 0.4669 - y1_output_root_mean_squared_error: 0.4187 - y2_output_root_mean_squared_error: 0.6837 - val_loss: 1.2232 - val_y1_output_loss: 0.2777 - val_y2_output_loss: 0.9079 - val_y1_output_root_mean_squared_error: 0.5366 - val_y2_output_root_mean_squared_error: 0.9671
# Epoch 118/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.1763 - y1_output_loss: 0.2545 - y2_output_loss: 0.9115 - y1_output_root_mean_squared_error: 0.5064 - y2_output_root_mean_squared_error: 0.9591 - val_loss: 1.3096 - val_y1_output_loss: 0.2875 - val_y2_output_loss: 0.9776 - val_y1_output_root_mean_squared_error: 0.5436 - val_y2_output_root_mean_squared_error: 1.0071
# Epoch 119/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.7779 - y1_output_loss: 0.2298 - y2_output_loss: 0.5571 - y1_output_root_mean_squared_error: 0.4727 - y2_output_root_mean_squared_error: 0.7446 - val_loss: 1.8040 - val_y1_output_loss: 0.6553 - val_y2_output_loss: 1.0994 - val_y1_output_root_mean_squared_error: 0.8213 - val_y2_output_root_mean_squared_error: 1.0628
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5896 - y1_output_loss: 0.1859 - y2_output_loss: 0.4032 - y1_output_root_mean_squared_error: 0.4313 - y2_output_root_mean_squared_error: 0.6353 - val_loss: 1.4323 - val_y1_output_loss: 0.2666 - val_y2_output_loss: 1.1163 - val_y1_output_root_mean_squared_error: 0.5229 - val_y2_output_root_mean_squared_error: 1.0765
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1263 - y1_output_loss: 0.0531 - y2_output_loss: 0.0730 - y1_output_root_mean_squared_error: 0.2311 - y2_output_root_mean_squared_error: 0.2700 - val_loss: 0.9448 - val_y1_output_loss: 0.1940 - val_y2_output_loss: 0.7195 - val_y1_output_root_mean_squared_error: 0.4475 - val_y2_output_root_mean_squared_error: 0.8629
# Epoch 462/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1243 - y1_output_loss: 0.0580 - y2_output_loss: 0.0661 - y1_output_root_mean_squared_error: 0.2405 - y2_output_root_mean_squared_error: 0.2578 - val_loss: 0.8013 - val_y1_output_loss: 0.1854 - val_y2_output_loss: 0.5888 - val_y1_output_root_mean_squared_error: 0.4380 - val_y2_output_root_mean_squared_error: 0.7807
# Epoch 463/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1347 - y1_output_loss: 0.0532 - y2_output_loss: 0.0810 - y1_output_root_mean_squared_error: 0.2309 - y2_output_root_mean_squared_error: 0.2852 - val_loss: 0.7893 - val_y1_output_loss: 0.1901 - val_y2_output_loss: 0.5748 - val_y1_output_root_mean_squared_error: 0.4416 - val_y2_output_root_mean_squared_error: 0.7709
# Epoch 464/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1317 - y1_output_loss: 0.0499 - y2_output_loss: 0.0816 - y1_output_root_mean_squared_error: 0.2223 - y2_output_root_mean_squared_error: 0.2868 - val_loss: 0.8592 - val_y1_output_loss: 0.2136 - val_y2_output_loss: 0.6167 - val_y1_output_root_mean_squared_error: 0.4702 - val_y2_output_root_mean_squared_error: 0.7988
# Epoch 465/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.1273 - y1_output_loss: 0.0553 - y2_output_loss: 0.0768 - y1_output_root_mean_squared_error: 0.2347 - y2_output_root_mean_squared_error: 0.2688 - val_loss: 2.1234 - val_y1_output_loss: 0.4340 - val_y2_output_loss: 1.6183 - val_y1_output_root_mean_squared_error: 0.6694 - val_y2_output_root_mean_squared_error: 1.2943
# Epoch 466/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1640 - y1_output_loss: 0.0739 - y2_output_loss: 0.0893 - y1_output_root_mean_squared_error: 0.2730 - y2_output_root_mean_squared_error: 0.2991 - val_loss: 0.8153 - val_y1_output_loss: 0.2225 - val_y2_output_loss: 0.5660 - val_y1_output_root_mean_squared_error: 0.4783 - val_y2_output_root_mean_squared_error: 0.7658
# Epoch 467/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1123 - y1_output_loss: 0.0510 - y2_output_loss: 0.0609 - y1_output_root_mean_squared_error: 0.2266 - y2_output_root_mean_squared_error: 0.2468 - val_loss: 1.0706 - val_y1_output_loss: 0.2347 - val_y2_output_loss: 0.8032 - val_y1_output_root_mean_squared_error: 0.4902 - val_y2_output_root_mean_squared_error: 0.9112
# Epoch 468/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1146 - y1_output_loss: 0.0488 - y2_output_loss: 0.0653 - y1_output_root_mean_squared_error: 0.2214 - y2_output_root_mean_squared_error: 0.2561 - val_loss: 0.7921 - val_y1_output_loss: 0.2034 - val_y2_output_loss: 0.5626 - val_y1_output_root_mean_squared_error: 0.4587 - val_y2_output_root_mean_squared_error: 0.7627
# Epoch 469/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2232 - y1_output_loss: 0.0852 - y2_output_loss: 0.1382 - y1_output_root_mean_squared_error: 0.2927 - y2_output_root_mean_squared_error: 0.3708 - val_loss: 0.8494 - val_y1_output_loss: 0.2434 - val_y2_output_loss: 0.5824 - val_y1_output_root_mean_squared_error: 0.4984 - val_y2_output_root_mean_squared_error: 0.7752
# Epoch 470/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1327 - y1_output_loss: 0.0582 - y2_output_loss: 0.0737 - y1_output_root_mean_squared_error: 0.2419 - y2_output_root_mean_squared_error: 0.2724 - val_loss: 0.7680 - val_y1_output_loss: 0.1807 - val_y2_output_loss: 0.5602 - val_y1_output_root_mean_squared_error: 0.4328 - val_y2_output_root_mean_squared_error: 0.7620
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1069 - y1_output_loss: 0.0482 - y2_output_loss: 0.0617 - y1_output_root_mean_squared_error: 0.2186 - y2_output_root_mean_squared_error: 0.2431 - val_loss: 1.6342 - val_y1_output_loss: 0.1816 - val_y2_output_loss: 1.4027 - val_y1_output_root_mean_squared_error: 0.4328 - val_y2_output_root_mean_squared_error: 1.2029
# Epoch 472/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.8143 - y1_output_loss: 0.1772 - y2_output_loss: 0.6304 - y1_output_root_mean_squared_error: 0.4227 - y2_output_root_mean_squared_error: 0.7973 - val_loss: 0.8966 - val_y1_output_loss: 0.2043 - val_y2_output_loss: 0.6697 - val_y1_output_root_mean_squared_error: 0.4567 - val_y2_output_root_mean_squared_error: 0.8294
# Epoch 473/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3791 - y1_output_loss: 0.1178 - y2_output_loss: 0.2585 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.5105 - val_loss: 0.9075 - val_y1_output_loss: 0.2036 - val_y2_output_loss: 0.6732 - val_y1_output_root_mean_squared_error: 0.4589 - val_y2_output_root_mean_squared_error: 0.8348
# Epoch 474/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.1406 - y1_output_loss: 0.0594 - y2_output_loss: 0.0852 - y1_output_root_mean_squared_error: 0.2379 - y2_output_root_mean_squared_error: 0.2899 - val_loss: 1.0020 - val_y1_output_loss: 0.3219 - val_y2_output_loss: 0.6526 - val_y1_output_root_mean_squared_error: 0.5715 - val_y2_output_root_mean_squared_error: 0.8218
# Epoch 475/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1432 - y1_output_loss: 0.0584 - y2_output_loss: 0.0882 - y1_output_root_mean_squared_error: 0.2386 - y2_output_root_mean_squared_error: 0.2938 - val_loss: 1.0052 - val_y1_output_loss: 0.2091 - val_y2_output_loss: 0.7617 - val_y1_output_root_mean_squared_error: 0.4659 - val_y2_output_root_mean_squared_error: 0.8878
# Epoch 476/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1381 - y1_output_loss: 0.0591 - y2_output_loss: 0.0779 - y1_output_root_mean_squared_error: 0.2441 - y2_output_root_mean_squared_error: 0.2803 - val_loss: 0.7952 - val_y1_output_loss: 0.1872 - val_y2_output_loss: 0.5823 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 0.7752
# Epoch 477/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.1290 - y1_output_loss: 0.0540 - y2_output_loss: 0.0741 - y1_output_root_mean_squared_error: 0.2332 - y2_output_root_mean_squared_error: 0.2731 - val_loss: 0.7766 - val_y1_output_loss: 0.1866 - val_y2_output_loss: 0.5639 - val_y1_output_root_mean_squared_error: 0.4392 - val_y2_output_root_mean_squared_error: 0.7640
# Epoch 478/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.1267 - y1_output_loss: 0.0523 - y2_output_loss: 0.0755 - y1_output_root_mean_squared_error: 0.2286 - y2_output_root_mean_squared_error: 0.2728 - val_loss: 1.1312 - val_y1_output_loss: 0.2101 - val_y2_output_loss: 0.8840 - val_y1_output_root_mean_squared_error: 0.4657 - val_y2_output_root_mean_squared_error: 0.9562
# Epoch 479/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1362 - y1_output_loss: 0.0560 - y2_output_loss: 0.0802 - y1_output_root_mean_squared_error: 0.2368 - y2_output_root_mean_squared_error: 0.2831 - val_loss: 0.8814 - val_y1_output_loss: 0.1927 - val_y2_output_loss: 0.6588 - val_y1_output_root_mean_squared_error: 0.4461 - val_y2_output_root_mean_squared_error: 0.8261
# Epoch 480/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1349 - y1_output_loss: 0.0545 - y2_output_loss: 0.0798 - y1_output_root_mean_squared_error: 0.2343 - y2_output_root_mean_squared_error: 0.2829 - val_loss: 0.9185 - val_y1_output_loss: 0.1804 - val_y2_output_loss: 0.7061 - val_y1_output_root_mean_squared_error: 0.4319 - val_y2_output_root_mean_squared_error: 0.8556
# Epoch 481/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1110 - y1_output_loss: 0.0480 - y2_output_loss: 0.0642 - y1_output_root_mean_squared_error: 0.2183 - y2_output_root_mean_squared_error: 0.2517 - val_loss: 1.2712 - val_y1_output_loss: 0.2593 - val_y2_output_loss: 0.9872 - val_y1_output_root_mean_squared_error: 0.5155 - val_y2_output_root_mean_squared_error: 1.0027
# Epoch 482/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1172 - y1_output_loss: 0.0478 - y2_output_loss: 0.0687 - y1_output_root_mean_squared_error: 0.2191 - y2_output_root_mean_squared_error: 0.2631 - val_loss: 0.8014 - val_y1_output_loss: 0.1956 - val_y2_output_loss: 0.5791 - val_y1_output_root_mean_squared_error: 0.4496 - val_y2_output_root_mean_squared_error: 0.7741
# Epoch 483/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1100 - y1_output_loss: 0.0540 - y2_output_loss: 0.0557 - y1_output_root_mean_squared_error: 0.2330 - y2_output_root_mean_squared_error: 0.2360 - val_loss: 0.8260 - val_y1_output_loss: 0.1819 - val_y2_output_loss: 0.6170 - val_y1_output_root_mean_squared_error: 0.4335 - val_y2_output_root_mean_squared_error: 0.7988
# Epoch 484/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1112 - y1_output_loss: 0.0467 - y2_output_loss: 0.0637 - y1_output_root_mean_squared_error: 0.2169 - y2_output_root_mean_squared_error: 0.2532 - val_loss: 0.7783 - val_y1_output_loss: 0.1916 - val_y2_output_loss: 0.5603 - val_y1_output_root_mean_squared_error: 0.4453 - val_y2_output_root_mean_squared_error: 0.7615
# Epoch 485/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.1126 - y1_output_loss: 0.0520 - y2_output_loss: 0.0603 - y1_output_root_mean_squared_error: 0.2283 - y2_output_root_mean_squared_error: 0.2459 - val_loss: 0.7845 - val_y1_output_loss: 0.1913 - val_y2_output_loss: 0.5713 - val_y1_output_root_mean_squared_error: 0.4445 - val_y2_output_root_mean_squared_error: 0.7661
# Epoch 486/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.0996 - y1_output_loss: 0.0486 - y2_output_loss: 0.0504 - y1_output_root_mean_squared_error: 0.2209 - y2_output_root_mean_squared_error: 0.2252 - val_loss: 0.7922 - val_y1_output_loss: 0.1765 - val_y2_output_loss: 0.5909 - val_y1_output_root_mean_squared_error: 0.4262 - val_y2_output_root_mean_squared_error: 0.7814
# Epoch 487/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1254 - y1_output_loss: 0.0480 - y2_output_loss: 0.0768 - y1_output_root_mean_squared_error: 0.2201 - y2_output_root_mean_squared_error: 0.2774 - val_loss: 0.9778 - val_y1_output_loss: 0.1952 - val_y2_output_loss: 0.7527 - val_y1_output_root_mean_squared_error: 0.4502 - val_y2_output_root_mean_squared_error: 0.8804
# Epoch 488/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.1097 - y1_output_loss: 0.0529 - y2_output_loss: 0.0564 - y1_output_root_mean_squared_error: 0.2304 - y2_output_root_mean_squared_error: 0.2379 - val_loss: 0.8196 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 0.5883 - val_y1_output_root_mean_squared_error: 0.4575 - val_y2_output_root_mean_squared_error: 0.7812
# Epoch 489/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1096 - y1_output_loss: 0.0526 - y2_output_loss: 0.0579 - y1_output_root_mean_squared_error: 0.2286 - y2_output_root_mean_squared_error: 0.2395 - val_loss: 0.7516 - val_y1_output_loss: 0.1806 - val_y2_output_loss: 0.5471 - val_y1_output_root_mean_squared_error: 0.4315 - val_y2_output_root_mean_squared_error: 0.7519
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.1131 - y1_output_loss: 0.0490 - y2_output_loss: 0.0657 - y1_output_root_mean_squared_error: 0.2195 - y2_output_root_mean_squared_error: 0.2549 - val_loss: 1.0663 - val_y1_output_loss: 0.2509 - val_y2_output_loss: 0.7844 - val_y1_output_root_mean_squared_error: 0.5064 - val_y2_output_root_mean_squared_error: 0.8999
# Epoch 491/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1107 - y1_output_loss: 0.0489 - y2_output_loss: 0.0621 - y1_output_root_mean_squared_error: 0.2210 - y2_output_root_mean_squared_error: 0.2487 - val_loss: 0.9379 - val_y1_output_loss: 0.2255 - val_y2_output_loss: 0.6860 - val_y1_output_root_mean_squared_error: 0.4787 - val_y2_output_root_mean_squared_error: 0.8418
# Epoch 492/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.1083 - y1_output_loss: 0.0463 - y2_output_loss: 0.0620 - y1_output_root_mean_squared_error: 0.2151 - y2_output_root_mean_squared_error: 0.2492 - val_loss: 0.8454 - val_y1_output_loss: 0.1975 - val_y2_output_loss: 0.6216 - val_y1_output_root_mean_squared_error: 0.4515 - val_y2_output_root_mean_squared_error: 0.8010
# Epoch 493/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1136 - y1_output_loss: 0.0511 - y2_output_loss: 0.0618 - y1_output_root_mean_squared_error: 0.2265 - y2_output_root_mean_squared_error: 0.2495 - val_loss: 0.8094 - val_y1_output_loss: 0.1955 - val_y2_output_loss: 0.5884 - val_y1_output_root_mean_squared_error: 0.4501 - val_y2_output_root_mean_squared_error: 0.7790
# Epoch 494/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1014 - y1_output_loss: 0.0498 - y2_output_loss: 0.0529 - y1_output_root_mean_squared_error: 0.2199 - y2_output_root_mean_squared_error: 0.2304 - val_loss: 0.8797 - val_y1_output_loss: 0.2714 - val_y2_output_loss: 0.5829 - val_y1_output_root_mean_squared_error: 0.5262 - val_y2_output_root_mean_squared_error: 0.7764
# Epoch 495/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1142 - y1_output_loss: 0.0530 - y2_output_loss: 0.0606 - y1_output_root_mean_squared_error: 0.2304 - y2_output_root_mean_squared_error: 0.2472 - val_loss: 0.8927 - val_y1_output_loss: 0.2336 - val_y2_output_loss: 0.6308 - val_y1_output_root_mean_squared_error: 0.4899 - val_y2_output_root_mean_squared_error: 0.8079
# Epoch 496/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1161 - y1_output_loss: 0.0506 - y2_output_loss: 0.0657 - y1_output_root_mean_squared_error: 0.2248 - y2_output_root_mean_squared_error: 0.2561 - val_loss: 1.0233 - val_y1_output_loss: 0.2148 - val_y2_output_loss: 0.7739 - val_y1_output_root_mean_squared_error: 0.4704 - val_y2_output_root_mean_squared_error: 0.8955
# Epoch 497/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.1059 - y1_output_loss: 0.0431 - y2_output_loss: 0.0626 - y1_output_root_mean_squared_error: 0.2076 - y2_output_root_mean_squared_error: 0.2506 - val_loss: 1.0027 - val_y1_output_loss: 0.2653 - val_y2_output_loss: 0.7044 - val_y1_output_root_mean_squared_error: 0.5238 - val_y2_output_root_mean_squared_error: 0.8534
# Epoch 498/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1157 - y1_output_loss: 0.0514 - y2_output_loss: 0.0667 - y1_output_root_mean_squared_error: 0.2277 - y2_output_root_mean_squared_error: 0.2526 - val_loss: 1.0389 - val_y1_output_loss: 0.2449 - val_y2_output_loss: 0.7606 - val_y1_output_root_mean_squared_error: 0.5012 - val_y2_output_root_mean_squared_error: 0.8875
# Epoch 499/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.1108 - y1_output_loss: 0.0467 - y2_output_loss: 0.0641 - y1_output_root_mean_squared_error: 0.2153 - y2_output_root_mean_squared_error: 0.2540 - val_loss: 0.9037 - val_y1_output_loss: 0.2355 - val_y2_output_loss: 0.6378 - val_y1_output_root_mean_squared_error: 0.4943 - val_y2_output_root_mean_squared_error: 0.8120
# Epoch 500/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.1234 - y1_output_loss: 0.0536 - y2_output_loss: 0.0692 - y1_output_root_mean_squared_error: 0.2325 - y2_output_root_mean_squared_error: 0.2634 - val_loss: 0.7769 - val_y1_output_loss: 0.1826 - val_y2_output_loss: 0.5688 - val_y1_output_root_mean_squared_error: 0.4342 - val_y2_output_root_mean_squared_error: 0.7671

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 37us/sample - loss: 0.7769 - y1_output_loss: 0.1854 - y2_output_loss: 0.5764 - y1_output_root_mean_squared_error: 0.4342 - y2_output_root_mean_squared_error: 0.7671
# Loss = 0.7769009974095729, Y1_loss = 0.18538418412208557, Y1_mse = 0.4341813027858734, Y2_loss = 0.5763505697250366, Y2_mse = 0.7670642733573914

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
